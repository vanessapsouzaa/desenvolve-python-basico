# %% [markdown]
# # Módulo 5 - Funções
#
# ## Aulas 5.2 - Funções Customizadas e 5.4 Funções ```lambda```

# %% [markdown]
# ### Q1.
#
# - Sabendo que o código a seguir calcula o fatorial de n, escreva uma função chamada ```fatorial()``` que recebe um inteiro ```n``` como parâmetro e retorna o resultado do fatorial de ```n```.
# - No programa principal, peça ao usuário o valor de ```n```, chame a sua função e imprima o retorno.
#
# ```python
# fat = 1
# for i in range(1, n+1):
#     fat *= i
# ```

# %%
def fatorial(n):
    fat = 1
    for i in range(1, n+1):
        fat *= i
    return fat

# %%
n = int(input("Digite n: "))
meu_fatorial = fatorial(n)
print(f"{n}! é {meu_fatorial}")
# Out:
# Digite n:  5
# 5! é 120

# %% [markdown]
# ### Q2.
#
# - Escreva uma função em Python chamada ```soma_quadrados``` que recebe dois números como parâmetros e retorna a soma dos seus quadrados.
# - No programa principal solicite ao usuário que insira dois números e utilize a função para exibir a soma dos quadrados.

# %%
def soma_quadrados(n, x):
    soma = n**2 + x**2
    return soma

# %%
n = int(input("Digite o primeiro número: "))
x = int(input("Digite o segundo número: "))
resultado = soma_quadrados (n, x)
print(f"A soma dos quadrados de {n} + {x} é {resultado} ")
# Out:
# Digite o primeiro número:  6
# Digite o segundo número:  2
# A soma dos quadrados de 6 + 2 é 40

# %% [markdown]
# ### Q3.
#
# - Crie uma função em Python chamada ```soma_digitos``` que recebe um número inteiro como parâmetro e retorna a soma dos seus dígitos. Por exemplo, para o número 123, a função deve retornar 6, $(1 + 2 + 3)$.
#     - O desafio aqui é separar os dígitos de um número inteiro usando operações aritméticas <br> <br>
#
# - No programa principal solicite ao usuário que insira um número e utilize a função ```soma_digitos``` para calcular e exibir a soma dos seus dígitos.

# %%
def soma_digitos (numero):
   
    soma = 0
    while numero > 0:
        soma += numero % 10  
        numero //= 10  
    return soma

# %%
numero = int(input("Digite um número inteiro: "))
resultado = soma_digitos(numero)
print(f"A soma dos dígitos do número {numero} é: {resultado}")
# Out:
# Digite um número inteiro:  725
# A soma dos dígitos do número 725 é: 14

# %% [markdown]
# ### Q4.
#
# - Crie a função ```inverteValor()``` que recebe um inteiro de qualquer tamanho e retorna esse valor invertido usando apenas operações aritméticas
# - Crie a função ```verificaInverso()``` que recebe o valor original e o valor invertido e retorna verdadeiro se ambos forem igualmente par ou igualmente ímpar. Retorne falso caso contrário.
# - No programa principal, peça um valor do usuário e imprima o retorno de ambas as funções.

# %%
def inverteValor(numero):
    numero_invertido = 0
    while numero > 0:
        digito = numero % 10  # Pega o último dígito
        numero_invertido = numero_invertido * 10 + digito  # Adiciona o dígito invertido ao número
        numero //= 10  # Remove o último dígito
    return numero_invertido

def verificaInverso(original, invertido):
    # Verifica se ambos os números são igualmente par ou igualmente ímpar
    if (original % 2 == invertido % 2):
        return True
    else:
        return False

# %%
numero = int(input("Digite um número inteiro: "))
numero_invertido = inverteValor(numero)
resultado_verifica = verificaInverso(numero, numero_invertido)

print(f"O número invertido de {numero} é {numero_invertido}")
print(f"A verificação de inverso é: {resultado_verifica}")
# Out:
# Digite um número inteiro:  89765
# O número invertido de 89765 é 56798
# A verificação de inverso é: False

# %% [markdown]
# ### Q5.
#
# Você está desenvolvendo um programa para auxiliar em cálculos de geometria básica. Crie as seguintes funções:
# - A função ```calcula_perimetro_triangulo()``` que recebe três inteiros correspondentes aos lados de um triângulo e retorna o perímetro do triângulo, ou seja, a soma dos seus lados.
# - A função ```calcula_perimetro_circulo()``` que recebe um inteiro referente ao raio do círculo e retorna o perímetro do círculo, dado por $2 \pi r$. Use a constante $\pi$ da biblioteca ```math```.
# - A função ```calcula_perimetro_retangulo()``` que possui um parâmetro obrigatório ```lado1``` e um opcional ```lado2```, ambos inteiros. Se o valor opcional não for fornecido, significa que se trata de um quadrado. Sua função deve calcular e retornar o perímetro do retângulo, ou seja, a soma de seus lados.
#     - Para o quadrado, é dado por $4 \times lado1$
#     - Para o retângulo é dado por $2 \times lado1 + 2 \times lado2$
#
# - No programa principal apresente um menu com as opções disponíveis do seu sistema e uma quarta opção ```Sair```. Solicite ao usuário a opção desejada, solicite as entradas correspondentes à opção escolhida, invoque a respective função e apresente o seu retorno. Seu programa deve retornar ao menu até que o usuário escolha a opção ```Sair```
#
# Exemplo de interação:
# ```
# 1 - Calcular perímetro triângulo
# 2 - Calcular perímetro círculo
# 3 - Calcular perímetro retângulo
# 4 - Sair
#
# Opção: 1
# Digite os três lados do triângulo:
# 3
# 4
# 5
# O perímetro é: 12
#
# 1 - Calcular perímetro triângulo
# 2 - Calcular perímetro círculo
# 3 - Calcular perímetro retângulo
# 4 - Sair
#
# Opção: 3
# Informe os dois lados do retângulo. Se for um quadrado, digite 0 para o segundo valor:
# 5
# 0
# O perímetro é: 20
#
# 1 - Calcular perímetro triângulo
# 2 - Calcular perímetro círculo
# 3 - Calcular perímetro retângulo
# 4 - Sair
#
# Opção: 4
# ```

# %%
import math

def calcula_perimetro_triangulo(lado1, lado2, lado3):
    return lado1 + lado2 + lado3

def calcula_perimetro_circulo(raio):
    return 2 * math.pi * raio

def calcula_perimetro_retangulo(lado1, lado2=0):
    if lado2 == 0:
        # Caso seja um quadrado
        return 4 * lado1
    else:
        # Caso seja um retângulo
        return 2 * (lado1 + lado2)

def menu():
    while True:
        print("\n1 - Calcular perímetro triângulo")
        print("2 - Calcular perímetro círculo")
        print("3 - Calcular perímetro retângulo")
        print("4 - Sair")
        
        opcao = int(input("Opção: "))
        if opcao == 1:
            # Calcular perímetro do triângulo
            print("Digite os três lados do triângulo:")
            lado1 = int(input())
            lado2 = int(input())
            lado3 = int(input())
            perimetro = calcula_perimetro_triangulo(lado1, lado2, lado3)
            print(f"O perímetro do triângulo é: {perimetro}")
        
        elif opcao == 2:
            # Calcular perímetro do círculo
            raio = int(input("Digite o raio do círculo: "))
            perimetro = calcula_perimetro_circulo(raio)
            print(f"O perímetro do círculo é: {perimetro}")
        
        elif opcao == 3:
            # Calcular perímetro do retângulo
            lado1 = int(input("Informe o primeiro lado do retângulo: "))
            lado2 = int(input("Informe o segundo lado do retângulo (se for um quadrado, digite 0): "))
            perimetro = calcula_perimetro_retangulo(lado1, lado2)
            print(f"O perímetro do retângulo (ou quadrado) é: {perimetro}")
        
        elif opcao == 4:
            print("Saindo...")
            break
        
        else:
            print("Opção inválida. Tente novamente.")

# %%
# Programa principal
menu()
# Out:
# 1 - Calcular perímetro triângulo
# 2 - Calcular perímetro círculo
# 3 - Calcular perímetro retângulo
# 4 - Sair
# Opção:  2
# Digite o raio do círculo:  6
# O perímetro do círculo é: 37.69911184307752
#
# 1 - Calcular perímetro triângulo
# 2 - Calcular perímetro círculo
# 3 - Calcular perímetro retângulo
# 4 - Sair
# Opção:  3
# Informe o primeiro lado do retângulo:  6
# Informe o segundo lado do retângulo (se for um quadrado, digite 0):  7
# O perímetro do retângulo (ou quadrado) é: 26
#
# 1 - Calcular perímetro triângulo
# 2 - Calcular perímetro círculo
# 3 - Calcular perímetro retângulo
# 4 - Sair
# Opção:  4
# Saindo...

# %% [markdown]
# ## Funções ```lambda```

# %% [markdown]
# ### Q6.
#
# Crie uma função lambda para verificar se um número é par ou ímpar. Em seguida, solicite ao usuário um número indefinidos de valores (até que o usuário digite 0). Para cada valor de entrada, informe se é par ou ímpar.
#
# Exemplo de interação:
# ```
# Digite os valores que deseja verificar a paridade (digite 0 para finalizar a entrada de dados):
# 3
# ímpar
# 8
# par
# 12
# par
# 5
# ímpar
# 7ímpar
# ```

# %%
# Função lambda para verificar se o número é par ou ímpar
verifica_paridade = lambda x: "par" if x % 2 == 0 else "ímpar"

# Solicitar valores ao usuário até que ele digite 0
print("Digite os valores que deseja verificar a paridade (digite 0 para finalizar a entrada de dados):")
while True:
    numero = int(input())
    
    if numero == 0:
        break
    
    # Verificar e exibir se o número é par ou ímpar
    print(verifica_paridade(numero))
# Out:
# Digite os valores que deseja verificar a paridade (digite 0 para finalizar a entrada de dados):
#  5
# ímpar
#  2
# par
#  0

# %% [markdown]
# ### Q7.
#
# Escreva um programa que pergunte ao usuário qual operação ele deseja: maior ou menor.
# Em seguida leia uma quantidade indefinida de valores do usuário, até que o usuário digite o valor zero.
# Apresente ao final o maior ou menor dos valores digitados de acordo com a escolha do usuário.
#
# **Sua solução deve incluir pelo menos uma função ```lambda```**
#
# Exemplo de interação:
# ```
# Opções: (1) maior ou (2) menor?
# Opção: 1
#
# Digite os valores de entrada. Digite 0 para finalizar a entrada de valores.
# 4
# 12
# 15
# 1
# 0
#
# O maior valor é: 15
# ```

# %%
## Escreva # Função lambda para determinar o maior ou menor valor
obter_valor = lambda lista, operacao: max(lista) if operacao == 1 else min(lista)

# Função principal
def main():
    # Perguntar a operação que o usuário deseja
    operacao = int(input("Opções: (1) maior ou (2) menor?\nOpção: "))
    
    if operacao not in [1, 2]:
        print("Opção inválida!")
        return
    
    # Lista para armazenar os valores digitados
    valores = []
    
    # Leitura dos valores até o usuário digitar 0
    print("Digite os valores de entrada. Digite 0 para finalizar a entrada de valores.")
    while True:
        valor = int(input())
        if valor == 0:
            break
        valores.append(valor)
    
    # Verificar se a lista tem ao menos um valor antes de realizar a operação
    if valores:
        resultado = obter_valor(valores, operacao)
        if operacao == 1:
            print(f"O maior valor é: {resultado}")
        else:
            print(f"O menor valor é: {resultado}")
    else:
        print("Nenhum valor foi digitado!")

# Executar o programa
main()
# Out:
# Opções: (1) maior ou (2) menor?
# Opção:  1
# Digite os valores de entrada. Digite 0 para finalizar a entrada de valores.
#  5
#  2
#  0
# O maior valor é: 5
