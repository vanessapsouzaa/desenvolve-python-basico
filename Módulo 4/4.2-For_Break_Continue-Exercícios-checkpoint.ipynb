# %% [markdown]
# # Módulo 4 - Repetições
#
# ## Aulas 4.2 - Comando ```for``` e 4.3 Break e Continue

# %% [markdown]
# ### Q1.
#
# Crie um programa em Python que utilize o comando for para imprimir os números de 10 a 1, em ordem decrescente.

# %%
# Loop for para imprimir os números de 10 a 1 em ordem decrescente
for i in range(10, 0, -1):
    print(i)

# %% [markdown]
# ### Q2.
#
# Dado um número inteiro positivo informado pelo usuário, crie um programa em Python que utilize o comando for para calcular e exibir a soma dos números de 1 até o número informado. Ou seja, $1 + 2 + 3 + ... + n$
#
# Exemplo de interação:
# ```
# Digite um número: 5
# A soma dos números de 1 a 5 é 15
# ```

# %%
# Solicita um número inteiro positivo ao usuário
numero = int(input("Digite um número: "))

# Inicializa a variável soma
soma = 0

# Loop for para somar os números de 1 até o número informado
for i in range(1, numero + 1):
    soma += i

# Exibe o resultado
print(f"A soma dos números de 1 a {numero} é {soma}")

# %% [markdown]
# ### Q3.
#
# Escreva um programa que lê 10 valores inteiros positivos do usuário e ao final imprime a média dos valores digitados com duas casas decimais.
#
# ```
# Digite 10 números positivos:
# 3
# 2
# 12
# 14
# 20
# 42
# 19
# 0
# 8
# 1
# A média dos valores digitados é 12.10
# ```

# %%
# Inicializa a variável para a soma dos números
soma = 0

# Solicita 10 números positivos e calcula a soma
print("Digite 10 números positivos:")
for i in range(10):
    numero = int(input())
    soma += numero

# Calcula a média
media = soma / 10

# Exibe a média com duas casas decimais
print(f"A média dos valores digitados é {media:.2f}")

# %% [markdown]
# ### Q4.
#
# Você vai criar um sistema que registra os resultados dos jogos do Atlético MG ao longo de um campeonato. Seu sistema vai receber os resultados de todos os jogos do Galo, e deve calcular a pontuação do time sabendo que vitórias valem 3 pontos, empates 1 ponto e derrotas 0 pontos.
#
# Entrada: <br>
# A primeira linha de entrada é um inteiro N com a quantidade jogos do galo. Para cada jogo você deve ler 2 inteiros, o primeiro com a quantidade de gols do galo e o segundo com a quantidade de gols do time oponente.
#
# Saída: <br>
# Apresente a soma de vitórias, empates e derrotas do galo, junto com o cálculo da pontuação total.
#
# Ex:
# ```
# Entrada:
# 4
# 2
# 0
# 1
# 1
# 0
# 3
# 1
# 0
#
# Saída:
# Vitórias: 2
# Empates: 1
# Derrotas: 1
# Pontuação: 7
#
# ```

# %%
# Lê o número de jogos
N = int(input())

# Inicializa as variáveis para contar vitórias, empates e derrotas
vitorias = 0
empates = 0
derrotas = 0

# Loop para processar os resultados dos jogos
for _ in range(N):
    # Lê a quantidade de gols do Galo e do time oponente
    gols_galo = int(input())
    gols_oponente = int(input())
    
    # Verifica o resultado do jogo
    if gols_galo > gols_oponente:
        vitorias += 1
    elif gols_galo == gols_oponente:
        empates += 1
    else:
        derrotas += 1

# Calcula a pontuação
pontuacao = vitorias * 3 + empates * 1

# Exibe o resultado
print(f"Vitórias: {vitorias}")
print(f"Empates: {empates}")
print(f"Derrotas: {derrotas}")
print(f"Pontuação: {pontuacao}")

# %% [markdown]
# ### Q5.
#
# Faça um programa que lê dois inteiros N e M, e imprime na tela um campo de batalha naval. O tabuleiro deve possuir N linhas e M colunas. A primeira linha é composta por um espaço em branco e o cabeçalho das colunas, ou seja, valores de 1 a M. As N linhas seguintes iniciam com o cabeçalho da linha, ou seja, seu número, seguido de M caracteres "/" (barra) indicando uma possível posição jogável.
#
# ```
# Entrada:
# 5
# 4
#
# Saída:
#   1 2 3 4
# 1 / / / /
# 2 / / / /
# 3 / / / /
# 4 / / / /
# 5 / / / /
# ```
#
# Para esse exercício, precisamos lembrar que o comando print implicitamente adiciona uma quebra de linha ao final da impressão. Podemos interferir no final da impressão adicionando mais uma entrada ao print. No exemplo, finalizamos cada linha com um espaço em branco:
# ```python
# print("Texto qualquer", end = " ")
# ```

# %%
# Lê os valores de N e M
N = int(input())
M = int(input())

# Imprime o cabeçalho da primeira linha
print(" ", end=" ")
for i in range(1, M + 1):
    print(i, end=" ")
print()

# Imprime as linhas subsequentes com seus respectivos números e barras
for i in range(1, N + 1):
    print(i, end=" ")
    for j in range(1, M + 1):
        print("/", end=" ")
    print()

# %% [markdown]
# ---
# ## Break e Continue

# %% [markdown]
# ### Q6.
#
# Escreva um programa que lê uma quantidade indefinida de valores e informa o maior e o menor valor digitados. A leitura é encerrada quando o usuário digitar o valor 0 (zero).
#
# ```
# Entrada:
# 12
# -1
# 29
# 11
# -5
# 0
#
# Saída:
# Maior: 29
# Menor: -5
# ```

# %%
# Inicializa as variáveis maior e menor com valores extremos
maior = float('-inf')  # Menor valor possível
menor = float('inf')  # Maior valor possível

# Laço para ler valores até o usuário digitar 0
while True:
    valor = int(input())  # Lê o valor digitado
    
    if valor == 0:
        break  # Encerra o laço quando o valor for 0
    
    # Atualiza o maior e o menor valor
    if valor > maior:
        maior = valor
    if valor < menor:
        menor = valor

# Imprime o maior e menor valor encontrados
print("Maior:", maior)
print("Menor:", menor)

# %% [markdown]
# ### Q7.
#
# Escreva um programa que lê uma quantidade indefinida de valores e informa o **produto** dos valores positivos digitados. A leitura é encerrada quando o usuário digitar o valor 0 (zero).
#
# ```
# Entrada:
# 2
# -1
# 1
# 3
# -5
# 0
#
# Saída:
# Produto: 6
# ```

# %%
# Inicializa o produto como 1, pois qualquer número multiplicado por 1 não altera o resultado.
produto = 1
# Flag para verificar se pelo menos um número positivo foi digitado
tem_positivo = False

# Laço para ler valores até o usuário digitar 0
while True:
    valor = int(input())  # Lê o valor digitado
    
    if valor == 0:
        break  # Encerra o laço quando o valor for 0
    
    if valor > 0:
        produto *= valor  # Multiplica o produto pelos valores positivos
        tem_positivo = True  # Marca que pelo menos um valor positivo foi digitado

# Imprime o produto, ou 0 caso nenhum valor positivo tenha sido digitado
if tem_positivo:
    print("Produto:", produto)
else:
    print("Produto: 0")

# %% [markdown]
# ### Q8.
#
# Vamos fazer uma calculadora que aceita expressões aritméticas de qualquer tamanho até que o usuário digite a palavra "Fim". Sua calculadora executa apenas as operações "+", "-".
#
# ```
# Entrada:
# 5
# +
# 8
# -
# 3
# +
# 2
# Fim
#
# Saída:
# 12
# ```

# %%
# Inicializa a variável para armazenar o resultado
resultado = 0

# Laço para receber os inputs do usuário até ele digitar 'Fim'
while True:
    numero = input()  # Lê o número ou operador
    if numero == "Fim":
        break  # Encerra o laço se o usuário digitar "Fim"
    
    operador = numero  # Armazena o operador ou o primeiro número
    numero = int(input())  # Lê o próximo número
    
    # Realiza a operação de acordo com o operador
    if operador == "+":
        resultado += numero
    elif operador == "-":
        resultado -= numero

# Imprime o resultado final
print(resultado)
